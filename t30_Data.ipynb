# %%
import pandas as pd

# %%
from io import StringIO
data ='{"Name":"Sourav Sharma","email":"souravbgp@gmail.com","Job":[{"title":"Sr.developer","title2":"Project Maneger"}]}'
df = pd.read_json(StringIO(data))
print(df)
# Out:
#             Name                email  \
# 0  Sourav Sharma  souravbgp@gmail.com
#
#                                                  Job
# 0  {'title': 'Sr.developer', 'title2': 'Project M...

# %%
df.to_json()
# Out:
# '{"Name":{"0":"Sourav Sharma"},"email":{"0":"souravbgp@gmail.com"},"Job":{"0":{"title":"Sr.developer","title2":"Project Maneger"}}}'

# %%
df.to_json(orient="index")
# Out:
# '{"0":{"Name":"Sourav Sharma","email":"souravbgp@gmail.com","Job":{"title":"Sr.developer","title2":"Project Maneger"}}}'

# %%
dataframe = pd.read_csv("wine.csv",header=None)

# %%
dataframe.head()
# Out:
#      0        1           2     3     4    5        6           7   \
# 0  Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids
# 1     1    14.23        1.71  2.43  15.6  127      2.8        3.06
# 2     1     13.2        1.78  2.14  11.2  100     2.65        2.76
# 3     1    13.16        2.36  2.67  18.6  101      2.8        3.24
# 4     1    14.37        1.95   2.5  16.8  113     3.85        3.49
#
#                      8        9          10    11    12       13
# 0  Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 1                   .28     2.29       5.64  1.04  3.92     1065
# 2                   .26     1.28       4.38  1.05   3.4     1050
# 3                    .3     2.81       5.68  1.03  3.17     1185
# 4                   .24     2.18        7.8   .86  3.45     1480

# %%
url = "https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/"
df2=pd.read_html(url,match="City")

# %%
df2[0]
# Out:
#                              Bank NameBank       CityCity StateSt  CertCert  \
# 0    Republic First Bank dba Republic Bank   Philadelphia      PA     27332
# 1                            Citizens Bank       Sac City      IA      8758
# 2                 Heartland Tri-State Bank        Elkhart      KS     25851
# 3                      First Republic Bank  San Francisco      CA     59017
# 4                           Signature Bank       New York      NY     57053
# ..                                     ...            ...     ...       ...
# 564                     Superior Bank, FSB       Hinsdale      IL     32646
# 565                    Malta National Bank          Malta      OH      6629
# 566        First Alliance Bank & Trust Co.     Manchester      NH     34264
# 567      National State Bank of Metropolis     Metropolis      IL      3815
# 568                       Bank of Honolulu       Honolulu      HI     21029
#
# ...
